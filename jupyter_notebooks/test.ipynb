# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv(r'C:\Users\rnr31\Documents\GitHub\apple_watch_tracker\dataset_5sec.csv')
data
# Out:
#       Unnamed: 0     id   time  activityrecognition#0  activityrecognition#1  \
# 0              0  16170   78.0                    NaN                  100.0
# 1              1  15871  145.0                    NaN                  100.0
# 2              2  16811  150.0                    NaN                  100.0
# 3              3  15831  105.0                    NaN                   77.0
# 4              4    876   77.0                    NaN                  100.0
# ...          ...    ...    ...                    ...                    ...
# 5888        5888  14125    4.0                    NaN                  100.0
# 5889        5889  19582   32.0                    NaN                   10.0
# 5890        5890  16178   86.0                    NaN                  100.0
# 5891        5891  10973  199.0                    NaN                  100.0
# 5892        5892   8278   55.0                    NaN                  100.0
#
# ...

# %%
for i in data.columns[2:]:
    cnt = data[f'{i}'].isnull().sum()
    if cnt>0:
        mn = data[f'{i}'].mean()
        data[f'{i}'] = data[f'{i}'].fillna(mn)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# id                          0
# time                        0
# activityrecognition#0    5893
# activityrecognition#1       0
#                          ...
# speed#min                   0
# speed#max                   0
# speed#std                   0
# target                      0
# user                        0
# Length: 71, dtype: int64

# %%
df['activityrecognition#1'].unique()
# Out:
# array([100.,  77.,  69.,  23.,  54.,  83.,  92.,  51.,  75.,   5.,  85.,
#         46.,  15.,  90.,   3.,   8.,  25.,  60.,  66.,  80.,  62.,  35.,
#         38.,  58.,  50.,  87.,  56.,  37.,  10.,  47.,  52.,  79.,  31.,
#         49.,  72.,  67.,  65.,  42.,  48.,  40.,  97.])

# %%
df1 =df.groupby(['target','activityrecognition#1'])
df1.head()
# Out:
#       Unnamed: 0     id   time  activityrecognition#0  activityrecognition#1  \
# 0              0  16170   78.0                    NaN                  100.0
# 1              1  15871  145.0                    NaN                  100.0
# 2              2  16811  150.0                    NaN                  100.0
# 3              3  15831  105.0                    NaN                   77.0
# 4              4    876   77.0                    NaN                  100.0
# ...          ...    ...    ...                    ...                    ...
# 5765        5765  15341   25.0                    NaN                   97.0
# 5783        5783  15340   24.0                    NaN                   97.0
# 5784        5784  20346    8.0                    NaN                   40.0
# 5801        5801  10827   53.0                    NaN                   87.0
# 5884        5884  19604   54.0                    NaN                    5.0
#
# ...

# %%
d = []
a = 'android.sensor.linear_acceleration#min'
b = a.split('.')[2].split('#')
d.append(f'{b[0]}_{b[1]}')
d
# Out:
# ['linear_acceleration_min']

# %%
a = 'android.sensor.linear_acceleration#min'
b = a.split('.')
b[0:2]
# Out:
# ['android', 'sensor']
