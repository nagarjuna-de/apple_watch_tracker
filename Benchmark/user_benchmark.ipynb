# %%
import time
from IPython.display import clear_output
import numpy    as np
import pandas   as pd
import seaborn  as sns
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
import sklearn  as skl
from numpy import asarray

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline      
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config

set_config(display='diagram') # Useful for display the pipeline
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
from sklearn.svm           import SVC

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
data = pd.read_csv(r'C:\Users\rnr31\Documents\GitHub\apple_watch_tracker\jupyter_notebooks\sort_dataset_5sec.csv')
#data

# %%
data_test = data.iloc[:2500, :]
data_train = data.iloc[2500: , :]
#data_test

# %%
def col_names_change(data):
    data.drop(['Unnamed: 0','id', 'activityrecognition#0','user'],axis=1, inplace=True)
    data_col = ['time','activityrecognition_1']
    for i in data.columns[2:58]:
        b = i.split('.')[2].split('#')
        data_col.append(f'{b[0]}_{b[1]}')

    for i in data.columns[58:66]:
        b = i.split('#')
        data_col.append(f'{b[0]}_{b[1]}')

    data_col.append('target')
    data = pd.DataFrame.from_records(data.values)
    data.columns = data_col

    return data

# %%
data_test = col_names_change(data_test)
data_train = col_names_change(data_train)
#data_train
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data_train['target']= data_train['target'].apply({'Bus':0, 'Car':1, 'Still':2, 'Train':3, 'Walking':4}.get)
data_test['target']= data_test['target'].apply({'Bus':0, 'Car':1, 'Still':2, 'Train':3, 'Walking':4}.get)

# %%
data_train = data_train.fillna(0)
data_test = data_test.fillna(0)

# %%
sns.countplot(data_test.target)
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
sns.countplot(data_train.target)
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
#### Training sets
x_train = data_train.iloc[:,:66]
y_train = data_train.iloc[:, 66:]

#### Testing sets
x_test = data_test.iloc[:, :66]
y_test = data_test.iloc[:, 66:]

# %%
x_train.head()
# Out:
#     time  activityrecognition_1  accelerometer_mean  accelerometer_min  \
# 0   45.0                  100.0            9.950332           8.410105
# 1   26.0                  100.0            9.841642           8.433949
# 2  201.0                   38.0            9.724502           9.702260
# 3  129.0                   69.0            9.787588           9.100255
# 4   60.0                  100.0            9.787193           9.741162
#
#    accelerometer_max  accelerometer_std  game_rotation_vector_mean  \
# 0          11.997985           0.766395                   0.969092
# 1          11.625431           0.757315                   0.938011
# 2           9.874900           0.026175                   0.999980
# 3          10.015627           0.145539                   0.999196
# 4           9.835721           0.022936                   0.397271
#
#    game_rotation_vector_min  game_rotation_vector_max  \
# 0                  0.963024                  0.980832
# 1                  0.936637                  0.943838
# 2                  0.999980                  0.999981
# 3                  0.998911                  0.999577
# 4                  0.394770                  0.402063
#
#    game_rotation_vector_std  ...  step_counter_max  step_counter_std  \
# 0              5.783952e-03  ...               0.0               0.0
# 1              1.966812e-03  ...               0.0               0.0
# 2              2.132909e-07  ...             785.0               0.0
# 3              2.352174e-04  ...            6803.0               0.0
# 4              2.399165e-03  ...            9198.0               0.0
#
#    sound_mean  sound_min  sound_max  sound_std  speed_mean  speed_min  \
# 0   73.017802  73.017802  73.017802   0.053353    7.457659   7.457659
# 1    0.000000   0.000000   0.000000   0.000000   10.476998  10.476998
# 2   65.796237  65.796237  65.796237  14.022096    0.001865   0.001865
# 3   78.197536  78.197536  78.197536   3.843737    0.860946   0.860946
# 4   60.365686  60.365686  60.365686   1.487859    0.000000   0.000000
#
#    speed_max  speed_std
# 0   7.457659    0.00000
# 1  10.476998    0.42211
# 2   0.001865    0.00000
# 3   0.860946    0.00000
# 4   0.000000    0.00000
#
# [5 rows x 66 columns]

# %%
x_train['gyroscope_std']
# Out:
# 0       0.034665
# 1       0.023221
# 2       0.000292
# 3       0.025989
# 4       0.316940
#           ...
# 3388    0.996347
# 3389    1.194949
# 3390    1.463428
# 3391    1.013326
# 3392    0.007948
# Name: gyroscope_std, Length: 3393, dtype: float64

# %%
tree_classifiers = {
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees": ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost": AdaBoostClassifier(n_estimators=100),
  "Skl GBM": GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM": HistGradientBoostingClassifier(max_iter=100),
  "XGBoost": XGBClassifier(n_estimators=100),
  "LightGBM": LGBMClassifier(n_estimators=100),
  "CatBoost":  CatBoostClassifier(n_estimators=100),
}

# %%
tree_classifiers = {name: make_pipeline(model) for name, model in tree_classifiers.items()}

results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

# %%
rang = abs(y_train.max()) + abs(y_train.min())
for model_name, model in tree_classifiers.items():
    
    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time() - start_time
        
    pred = model.predict(x_test)
    
    results = results.append({"Model":    model_name,
                              "Accuracy": accuracy_score(y_test, pred)*100,
                              "Bal Acc.": balanced_accuracy_score(y_test, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [20:54:07] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Learning rate set to 0.5
# 0:	learn: 0.9057873	total: 215ms	remaining: 21.3s
# 1:	learn: 0.6710922	total: 251ms	remaining: 12.3s
# 2:	learn: 0.5424035	total: 288ms	remaining: 9.32s
# 3:	learn: 0.4550630	total: 325ms	remaining: 7.81s
# 4:	learn: 0.3865361	total: 362ms	remaining: 6.87s
# 5:	learn: 0.3369850	total: 399ms	remaining: 6.25s
# 6:	learn: 0.2856685	total: 435ms	remaining: 5.77s
# 7:	learn: 0.2573170	total: 475ms	remaining: 5.46s
# 8:	learn: 0.2339398	total: 511ms	remaining: 5.17s
# 9:	learn: 0.2121946	total: 554ms	remaining: 4.99s
# 10:	learn: 0.1960446	total: 594ms	remaining: 4.81s
# 11:	learn: 0.1823096	total: 635ms	remaining: 4.65s
# 12:	learn: 0.1637905	total: 674ms	remaining: 4.51s
# 13:	learn: 0.1540224	total: 716ms	remaining: 4.4s
# 14:	learn: 0.1430181	total: 753ms	remaining: 4.26s
# 15:	learn: 0.1349853	total: 791ms	remaining: 4.15s
# 16:	learn: 0.1312751	total: 827ms	remaining: 4.04s
# 17:	learn: 0.1276920	total: 862ms	remaining: 3.93s
# 18:	learn: 0.1203083	total: 902ms	remaining: 3.84s
# 19:	learn: 0.1135173	total: 941ms	remaining: 3.77s
# 20:	learn: 0.1077812	total: 979ms	remaining: 3.68s
# 21:	learn: 0.1046561	total: 1.01s	remaining: 3.6s
# 22:	learn: 0.1008014	total: 1.05s	remaining: 3.52s
# 23:	learn: 0.0976466	total: 1.09s	remaining: 3.45s
# 24:	learn: 0.0953555	total: 1.13s	remaining: 3.38s
# 25:	learn: 0.0912259	total: 1.17s	remaining: 3.32s
# 26:	learn: 0.0894120	total: 1.21s	remaining: 3.28s
# 27:	learn: 0.0878668	total: 1.25s	remaining: 3.23s
# 28:	learn: 0.0855010	total: 1.29s	remaining: 3.17s
# 29:	learn: 0.0820454	total: 1.33s	remaining: 3.12s
# 30:	learn: 0.0789614	total: 1.38s	remaining: 3.07s
# 31:	learn: 0.0773112	total: 1.42s	remaining: 3.03s
# 32:	learn: 0.0745276	total: 1.47s	remaining: 2.98s
# 33:	learn: 0.0711957	total: 1.5s	remaining: 2.92s
# 34:	learn: 0.0695384	total: 1.54s	remaining: 2.86s
# 35:	learn: 0.0684550	total: 1.58s	remaining: 2.8s
# 36:	learn: 0.0662834	total: 1.62s	remaining: 2.76s
# 37:	learn: 0.0639003	total: 1.66s	remaining: 2.71s
# 38:	learn: 0.0618895	total: 1.7s	remaining: 2.66s
# 39:	learn: 0.0607508	total: 1.74s	remaining: 2.61s
# 40:	learn: 0.0593761	total: 1.78s	remaining: 2.56s
# 41:	learn: 0.0578550	total: 1.81s	remaining: 2.51s
# 42:	learn: 0.0567100	total: 1.86s	remaining: 2.46s
# 43:	learn: 0.0546922	total: 1.9s	remaining: 2.41s
# 44:	learn: 0.0534465	total: 1.93s	remaining: 2.36s
# 45:	learn: 0.0516743	total: 1.97s	remaining: 2.31s
# 46:	learn: 0.0505016	total: 2.01s	remaining: 2.26s
# 47:	learn: 0.0495057	total: 2.05s	remaining: 2.22s
# 48:	learn: 0.0487930	total: 2.09s	remaining: 2.17s
# 49:	learn: 0.0481810	total: 2.12s	remaining: 2.12s
# 50:	learn: 0.0467042	total: 2.16s	remaining: 2.07s
# 51:	learn: 0.0459830	total: 2.2s	remaining: 2.03s
# 52:	learn: 0.0451172	total: 2.23s	remaining: 1.98s
# 53:	learn: 0.0444513	total: 2.27s	remaining: 1.93s
# 54:	learn: 0.0434650	total: 2.31s	remaining: 1.89s
# 55:	learn: 0.0426128	total: 2.35s	remaining: 1.84s
# 56:	learn: 0.0419255	total: 2.39s	remaining: 1.8s
# 57:	learn: 0.0413396	total: 2.42s	remaining: 1.75s
# 58:	learn: 0.0408944	total: 2.46s	remaining: 1.71s
# 59:	learn: 0.0398318	total: 2.5s	remaining: 1.66s
# 60:	learn: 0.0390394	total: 2.53s	remaining: 1.62s
# 61:	learn: 0.0386070	total: 2.57s	remaining: 1.57s
# 62:	learn: 0.0377512	total: 2.62s	remaining: 1.53s
# 63:	learn: 0.0356426	total: 2.65s	remaining: 1.49s
# 64:	learn: 0.0350147	total: 2.69s	remaining: 1.45s
# 65:	learn: 0.0348554	total: 2.73s	remaining: 1.41s
# 66:	learn: 0.0345726	total: 2.77s	remaining: 1.36s
# 67:	learn: 0.0342944	total: 2.85s	remaining: 1.34s
# 68:	learn: 0.0332143	total: 2.9s	remaining: 1.3s
# 69:	learn: 0.0326297	total: 2.96s	remaining: 1.27s
# 70:	learn: 0.0320361	total: 3s	remaining: 1.23s
# 71:	learn: 0.0316485	total: 3.04s	remaining: 1.18s
# 72:	learn: 0.0302751	total: 3.08s	remaining: 1.14s
# 73:	learn: 0.0298713	total: 3.13s	remaining: 1.1s
# 74:	learn: 0.0295268	total: 3.18s	remaining: 1.06s
# 75:	learn: 0.0293280	total: 3.23s	remaining: 1.02s
# 76:	learn: 0.0283955	total: 3.27s	remaining: 975ms
# 77:	learn: 0.0279715	total: 3.3s	remaining: 931ms
# 78:	learn: 0.0268064	total: 3.34s	remaining: 887ms
# 79:	learn: 0.0260590	total: 3.37s	remaining: 843ms
# 80:	learn: 0.0254368	total: 3.41s	remaining: 799ms
# 81:	learn: 0.0249649	total: 3.44s	remaining: 756ms
# 82:	learn: 0.0243380	total: 3.49s	remaining: 715ms
# 83:	learn: 0.0241454	total: 3.53s	remaining: 672ms
# 84:	learn: 0.0233063	total: 3.56s	remaining: 629ms
# 85:	learn: 0.0230825	total: 3.6s	remaining: 586ms
# 86:	learn: 0.0228667	total: 3.63s	remaining: 543ms
# 87:	learn: 0.0224369	total: 3.67s	remaining: 500ms
# 88:	learn: 0.0222839	total: 3.71s	remaining: 458ms
# 89:	learn: 0.0219283	total: 3.75s	remaining: 417ms
# 90:	learn: 0.0217088	total: 3.79s	remaining: 375ms
# 91:	learn: 0.0214022	total: 3.83s	remaining: 333ms
# 92:	learn: 0.0212557	total: 3.87s	remaining: 291ms
# 93:	learn: 0.0209082	total: 3.91s	remaining: 249ms
# 94:	learn: 0.0206315	total: 3.94s	remaining: 208ms
# 95:	learn: 0.0203068	total: 3.98s	remaining: 166ms
# 96:	learn: 0.0200153	total: 4.03s	remaining: 125ms
# 97:	learn: 0.0197740	total: 4.07s	remaining: 83ms
# 98:	learn: 0.0195302	total: 4.1s	remaining: 41.5ms
# 99:	learn: 0.0193154	total: 4.16s	remaining: 0us
# <style  type="text/css" >
# #T_a15ba12f_af91_11ec_806f_48a472d2776erow0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 64.6%, transparent 64.6%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 61.1%, transparent 61.1%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 60.4%, transparent 60.4%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 62.3%, transparent 62.3%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 58.9%, transparent 58.9%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 59.8%, transparent 59.8%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 58.4%, transparent 58.4%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 59.9%, transparent 59.9%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 57.6%, transparent 57.6%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 59.0%, transparent 59.0%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 53.8%, transparent 53.8%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 55.3%, transparent 55.3%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 50.5%, transparent 50.5%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 54.1%, transparent 54.1%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 47.7%, transparent 47.7%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 48.0%, transparent 48.0%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 46.9%, transparent 46.9%);
#         }#T_a15ba12f_af91_11ec_806f_48a472d2776erow8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 49.8%, transparent 49.8%);
#         }</style><table id="T_a15ba12f_af91_11ec_806f_48a472d2776e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a15ba12f_af91_11ec_806f_48a472d2776elevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow0_col0" class="data row0 col0" >Extra Trees</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow0_col1" class="data row0 col1" >64.560000</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow0_col2" class="data row0 col2" >61.051512</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow0_col3" class="data row0 col3" >0.342676</td>
#             </tr>
#             <tr>
#                         <th id="T_a15ba12f_af91_11ec_806f_48a472d2776elevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow1_col0" class="data row1 col0" >CatBoost</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow1_col1" class="data row1 col1" >60.400000</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow1_col2" class="data row1 col2" >62.262732</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow1_col3" class="data row1 col3" >4.316001</td>
#             </tr>
#             <tr>
#                         <th id="T_a15ba12f_af91_11ec_806f_48a472d2776elevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow2_col0" class="data row2 col0" >Skl HistGBM</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow2_col1" class="data row2 col1" >58.880000</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow2_col2" class="data row2 col2" >59.810007</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow2_col3" class="data row2 col3" >6.915471</td>
#             </tr>
#             <tr>
#                         <th id="T_a15ba12f_af91_11ec_806f_48a472d2776elevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow3_col0" class="data row3 col0" >Random Forest</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow3_col1" class="data row3 col1" >58.360000</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow3_col2" class="data row3 col2" >59.930332</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow3_col3" class="data row3 col3" >0.966972</td>
#             </tr>
#             <tr>
#                         <th id="T_a15ba12f_af91_11ec_806f_48a472d2776elevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow4_col0" class="data row4 col0" >LightGBM</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow4_col1" class="data row4 col1" >57.560000</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow4_col2" class="data row4 col2" >59.037283</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow4_col3" class="data row4 col3" >1.380309</td>
#             </tr>
#             <tr>
#                         <th id="T_a15ba12f_af91_11ec_806f_48a472d2776elevel0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow5_col0" class="data row5 col0" >XGBoost</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow5_col1" class="data row5 col1" >53.760000</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow5_col2" class="data row5 col2" >55.333157</td>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow5_col3" class="data row5 col3" >2.013615</td>
#             </tr>
#             <tr>
#                         <th id="T_a15ba12f_af91_11ec_806f_48a472d2776elevel0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_a15ba12f_af91_11ec_806f_48a472d2776erow6_col0" class="data row6 col0" >AdaBoost</td>
#                         <td i

# %%
results_ord
# Out:
#            Model  Accuracy   Bal Acc.       Time
# 1    Extra Trees     64.56  61.051512   0.342676
# 2       CatBoost     60.40  62.262732   4.316001
# 3    Skl HistGBM     58.88  59.810007   6.915471
# 4  Random Forest     58.36  59.930332   0.966972
# 5       LightGBM     57.56  59.037283   1.380309
# 6        XGBoost     53.76  55.333157   2.013615
# 7       AdaBoost     50.48  54.134368   1.577080
# 8        Skl GBM     47.72  48.026208  17.127564
# 9  Decision Tree     46.88  49.757551   0.143252
