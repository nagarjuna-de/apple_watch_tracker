# %%
import time
from IPython.display import clear_output
import numpy    as np
import pandas   as pd
import seaborn  as sns
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
import sklearn  as skl
from numpy import asarray

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline      
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config

set_config(display='diagram') # Useful for display the pipeline
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
from sklearn.svm           import SVC

# %%
data = pd.read_csv(r'C:\Users\rnr31\Documents\GitHub\apple_watch_tracker\Datasets\dataset_0.5sec.csv')

# %%
oe = OrdinalEncoder()
ct = asarray(data['user'])
data['user'] = oe.fit_transform(ct.reshape(-1,1))
data = data.sort_values(by='user')
data
# Out:
#        Unnamed: 0      id    time  activityrecognition#0  \
# 62584       62584   84508   630.0                    NaN
# 21106       21106    8609   234.0                    NaN
# 21105       21105   22422  1727.0                    NaN
# 21104       21104   11240  1151.0                    NaN
# 21103       21103    7828   289.0                    NaN
# ...           ...     ...     ...                    ...
# 37690       37690  129745   309.0                    NaN
# 37689       37689  129760   324.0                    NaN
# 37688       37688  131014  1578.0                    NaN
# 37699       37699  130782  1346.0                    NaN
# 52624       52624  131097    74.0                    NaN
#
#        activityrecognition#1  android.sensor.accelerometer#mean  \
# 62584                  100.0                          15.892297
# 21106                  100.0                          10.142241
# 21105                    8.0                          10.033811
# 21104                  100.0                          10.044192
# 21103                   85.0                           8.514446
# ...                      ...                                ...
# 37690                    8.0                          10.805771
# 37689                    8.0                          10.389200
# 37688                    8.0                          10.718977
# 37699                    8.0                          10.551876
# 52624                  100.0                           7.831070
#
#        android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 62584                         15.892297                         15.892297
# 21106                         10.142241                         10.142241
# 21105                          9.701954                         10.334343
# 21104                          9.843447                         10.144604
# 21103                          8.514446                          8.514446
# ...                                 ...                               ...
# 37690                         10.805771                         10.805771
# 37689                         10.389200                         10.389200
# 37688                         10.704910                         10.733045
# 37699                         10.463580                         10.686567
# 52624                          4.649800                         11.012339
#
#        android.sensor.accelerometer#std  \
# 62584                          3.606631
# 21106                          0.007413
# 21105                          0.317356
# 21104                          0.173851
# 21103                          0.062750
# ...                                 ...
# 37690                          0.102640
# 37689                          0.019366
# 37688                          0.019895
# 37699                          0.118512
# 52624                          4.498995
#
#        android.sensor.game_rotation_vector#mean  ...  sound#mean  sound#min  \
# 62584                                  0.838142  ...   89.730876  89.730876
# 21106                                  0.840593  ...   89.770732  89.770732
# 21105                                  0.890862  ...   89.794108  89.794108
# 21104                                  0.772161  ...         NaN        NaN
# 21103                                  0.734319  ...   89.738523  89.738523
# ...                                         ...  ...         ...        ...
# 37690                                       NaN  ...   71.595672  71.595672
# 37689                                       NaN  ...   68.089832  68.089832
# 37688                                       NaN  ...   70.312179  70.312179
# 37699                                       NaN  ...   68.048667  68.048667
# 52624                                       NaN  ...   72.281062  72.281062
#
#        sound#max  sound#std  speed#mean  speed#min  speed#max  speed#std  \
# 62584  89.730876        NaN        0.75       0.75       0.75        NaN
# 21106  89.770732        NaN       13.50      13.50      13.50        NaN
# 21105  89.794108        NaN       20.50      20.50      20.50        NaN
# 21104        NaN        NaN       32.50      32.50      32.50        NaN
# 21103  89.738523        NaN       12.25      12.25      12.25        NaN
# ...          ...        ...         ...        ...        ...        ...
# 37690  71.595672        NaN         NaN        NaN        NaN        NaN
# 37689  68.089832        NaN         NaN        NaN        NaN        NaN
# 37688  70.312179        NaN         NaN        NaN        NaN        NaN
# 37699  68.048667        NaN         NaN        NaN        NaN        NaN
# 52624  72.281062        NaN         NaN        NaN        NaN        NaN
#
#         target  user
# 62584  Walking   0.0
# 21106      Car   0.0
# 21105      Car   0.0
# 21104      Car   0.0
# 21103      Car   0.0
# ...        ...   ...
# 37690    Train  12.0
# 37689    Train  12.0
# 37688    Train  12.0
# 37699    Train  12.0
# 52624  Walking  12.0
#
# [62585 rows x 71 columns]

# %%
def col_names_change(data):
    data.drop(['Unnamed: 0','id', 'activityrecognition#0'],axis=1, inplace=True)
    data_col = ['time','activityrecognition_1']
    for i in data.columns[2:58]:
        b = i.split('.')[2].split('#')
        data_col.append(f'{b[0]}_{b[1]}')

    for i in data.columns[58:66]:
        b = i.split('#')
        data_col.append(f'{b[0]}_{b[1]}')

    data_col.append('target')
    data_col.append('user')
    data = pd.DataFrame.from_records(data.values)
    data.columns = data_col

    return data

# %%
data = col_names_change(data)

# %%
data.drop(['pressure_mean', 'pressure_max', 'pressure_min', 'pressure_std', 'sound_std', 'speed_std','step_counter_mean','step_counter_std','light_std',
            'proximity_mean','proximity_min','proximity_max','proximity_std', 'step_counter_min', 'step_counter_max' ], axis=1, inplace=True)

# %%
data['target']= data['target'].apply({'Bus':0, 'Car':1, 'Still':2, 'Train':3, 'Walking':4}.get)

# %%
df0 = data[data['target']==0]
df1 = data[data['target']==1]
df2 = data[data['target']==2]
df3 = data[data['target']==3]
df4 = data[data['target']==4]
#msno.matrix(df1)

# %%
def fill_nan_values(tsdf):
    for i in tsdf.columns:
        ndf = tsdf.groupby(['target'])[f'{i}'].mean()
        mn = ndf.values[0]
        tsdf[f'{i}'] = tsdf[f'{i}'].fillna(mn)
    return tsdf

df0 = fill_nan_values(df0)
df1 = fill_nan_values(df1)
df2 = fill_nan_values(df2)
df3 = fill_nan_values(df3)
df4 = fill_nan_values(df4)
# Out:
# C:\Users\rnr31\AppData\Local\Temp\ipykernel_14076\154742137.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tsdf[f'{i}'] = tsdf[f'{i}'].fillna(mn)

# %%
data = pd.concat([df0, df1, df2, df3, df4])
data.shape
# Out:
# (62585, 53)

# %%
data
# Out:
#         time  activityrecognition_1  accelerometer_mean  accelerometer_min  \
# 13713  821.0                  100.0            9.580663           9.580663
# 13714   13.0                  100.0           10.958598           9.868953
# 13715   12.0                  100.0           10.958598           9.868953
# 13716   11.0                  100.0            8.841528           6.835641
# 13717   10.0                  100.0           11.618934           9.715548
# ...      ...                    ...                 ...                ...
# 62145  483.0                  100.0           10.265969           8.937641
# 62146  418.0                  100.0           14.321415          14.321415
# 62147  546.0                  100.0           25.482379          25.482379
# 62529  854.0                   85.0           13.730206          13.730206
# 62584   74.0                  100.0            7.831070           4.649800
#
#        accelerometer_max  accelerometer_std  game_rotation_vector_mean  \
# 13713           9.580663           0.012232                   0.801618
# 13714          12.048243           1.540991                   0.779063
# 13715          12.048243           1.540991                   0.779063
# 13716          10.847415           2.836753                   0.779063
# 13717          13.385976           1.839009                   0.779063
# ...                  ...                ...                        ...
# 62145          11.594297           1.878540                   0.870339
# 62146          14.321415           3.729311                   0.870339
# 62147          25.482379           1.884572                   0.870339
# 62529          13.730206           1.836736                   0.870339
# 62584          11.012339           4.498995                   0.870339
#
#        game_rotation_vector_min  game_rotation_vector_max  \
# 13713                  0.801618                  0.801618
# 13714                  0.779063                  0.779063
# 13715                  0.779063                  0.779063
# 13716                  0.779063                  0.779063
# 13717                  0.779063                  0.779063
# ...                         ...                       ...
# 62145                  0.862206                  0.876766
# 62146                  0.862206                  0.876766
# 62147                  0.862206                  0.876766
# 62529                  0.862206                  0.876766
# 62584                  0.862206                  0.876766
#
#        game_rotation_vector_std  ...  rotation_vector_max  \
# 13713                  0.000162  ...             0.928278
# 13714                  0.004365  ...             0.482034
# 13715                  0.004365  ...             0.452277
# 13716                  0.004365  ...             0.452277
# 13717                  0.004365  ...             0.417588
# ...                         ...  ...                  ...
# 62145                  0.015529  ...             0.972661
# 62146                  0.015529  ...             0.879428
# 62147                  0.015529  ...             0.854721
# 62529                  0.015529  ...             0.996823
# 62584                  0.015529  ...             0.817068
#
#        rotation_vector_std  sound_mean  sound_min  sound_max  speed_mean  \
# 13713             0.000081   85.121360  85.121360  85.121360    8.000000
# 13714             0.008963   83.843193  83.843144  83.843242    5.341548
# 13715             0.004023   83.843193  83.843144  83.843242    5.341548
# 13716             0.004023   83.843193  83.843144  83.843242    5.341548
# 13717             0.004023   83.843193  83.843144  83.843242    5.341548
# ...                    ...         ...        ...        ...         ...
# 62145             0.016987   73.757710  73.757710  73.757710    1.178197
# 62146             0.004941   79.568839  79.567896  79.569832    1.178197
# 62147             0.029765   79.568839  79.567896  79.569832    1.178197
# 62529             0.001330   78.116997  78.116997  78.116997    1.178197
# 62584             0.033511   72.281062  72.281062  72.281062    1.178197
#
#        speed_min  speed_max  target  user
# 13713   8.000000   8.000000       0   0.0
# 13714   5.341548   5.341548       0   0.0
# 13715   5.341548   5.341548       0   0.0
# 13716   5.341548   5.341548       0   0.0
# 13717   5.341548   5.341548       0   0.0
# ...          ...        ...     ...   ...
# 62145   1.178197   1.178197       4  12.0
# 62146   1.178197   1.178197       4  12.0
# 62147   1.178197   1.178197       4  12.0
# 62529   1.178197   1.178197       4  12.0
# 62584   1.178197   1.178197       4  12.0
#
# [62585 rows x 53 columns]

# %%
data = data.sort_values(by='user')
data.drop(['user'], axis=1, inplace=True)

# %%
data_test = data.iloc[:26000, :]
data_train = data.iloc[26000: , :]

#### Training sets
x_train = data_train.drop(['target'], axis=1)
y_train = data_train['target']

#### Testing sets
x_test = data_test.drop(['target'], axis=1)
y_test = data_test['target']

# %%
y_train.unique()
# Out:
# array([2, 4, 1, 0, 3], dtype=int64)

# %%
y_test.unique()
# Out:
# array([0, 3, 1, 2, 4], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler = scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
tree_classifiers = {
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees": ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost": AdaBoostClassifier(n_estimators=100),
  "Skl GBM": GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM": HistGradientBoostingClassifier(max_iter=100),
  "XGBoost": XGBClassifier(n_estimators=100),
  "LightGBM": LGBMClassifier(n_estimators=100),
  "CatBoost":  CatBoostClassifier(n_estimators=100),
}

# %%
tree_classifiers = {name: make_pipeline(model) for name, model in tree_classifiers.items()}

results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

# %%
rang = abs(y_train.max()) + abs(y_train.min())
for model_name, model in tree_classifiers.items():
    
    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time() - start_time
        
    pred = model.predict(x_test)
    
    results = results.append({"Model":    model_name,
                              "Accuracy": accuracy_score(y_test, pred)*100,
                              "Bal Acc.": balanced_accuracy_score(y_test, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:38:21] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.5
# 0:	learn: 0.5750207	total: 269ms	remaining: 26.6s
# 1:	learn: 0.4011415	total: 380ms	remaining: 18.6s
# 2:	learn: 0.2848438	total: 507ms	remaining: 16.4s
# 3:	learn: 0.2162873	total: 620ms	remaining: 14.9s
# 4:	learn: 0.1738717	total: 726ms	remaining: 13.8s
# 5:	learn: 0.1361200	total: 849ms	remaining: 13.3s
# 6:	learn: 0.1081111	total: 947ms	remaining: 12.6s
# 7:	learn: 0.0939116	total: 1.08s	remaining: 12.4s
# 8:	learn: 0.0833006	total: 1.18s	remaining: 12s
# 9:	learn: 0.0728171	total: 1.26s	remaining: 11.4s
# 10:	learn: 0.0580176	total: 1.36s	remaining: 11s
# 11:	learn: 0.0519142	total: 1.6s	remaining: 11.7s
# 12:	learn: 0.0458450	total: 1.73s	remaining: 11.6s
# 13:	learn: 0.0410577	total: 1.83s	remaining: 11.3s
# 14:	learn: 0.0380115	total: 1.9s	remaining: 10.8s
# 15:	learn: 0.0338059	total: 1.97s	remaining: 10.3s
# 16:	learn: 0.0304289	total: 2.05s	remaining: 10s
# 17:	learn: 0.0264975	total: 2.14s	remaining: 9.77s
# 18:	learn: 0.0253379	total: 2.22s	remaining: 9.47s
# 19:	learn: 0.0233909	total: 2.29s	remaining: 9.16s
# 20:	learn: 0.0216537	total: 2.36s	remaining: 8.88s
# 21:	learn: 0.0194819	total: 2.47s	remaining: 8.75s
# 22:	learn: 0.0184424	total: 2.56s	remaining: 8.58s
# 23:	learn: 0.0171864	total: 2.65s	remaining: 8.39s
# 24:	learn: 0.0164609	total: 2.74s	remaining: 8.21s
# 25:	learn: 0.0160365	total: 2.82s	remaining: 8.02s
# 26:	learn: 0.0147729	total: 2.91s	remaining: 7.86s
# 27:	learn: 0.0138225	total: 2.98s	remaining: 7.68s
# 28:	learn: 0.0130177	total: 3.07s	remaining: 7.51s
# 29:	learn: 0.0124653	total: 3.17s	remaining: 7.4s
# 30:	learn: 0.0120642	total: 3.25s	remaining: 7.24s
# 31:	learn: 0.0116740	total: 3.32s	remaining: 7.05s
# 32:	learn: 0.0109851	total: 3.44s	remaining: 6.97s
# 33:	learn: 0.0105538	total: 3.56s	remaining: 6.91s
# 34:	learn: 0.0100534	total: 3.66s	remaining: 6.8s
# 35:	learn: 0.0098681	total: 3.73s	remaining: 6.63s
# 36:	learn: 0.0093651	total: 3.79s	remaining: 6.45s
# 37:	learn: 0.0091312	total: 3.86s	remaining: 6.3s
# 38:	learn: 0.0085054	total: 3.97s	remaining: 6.21s
# 39:	learn: 0.0080272	total: 4.11s	remaining: 6.17s
# 40:	learn: 0.0074707	total: 4.22s	remaining: 6.07s
# 41:	learn: 0.0072790	total: 4.29s	remaining: 5.93s
# 42:	learn: 0.0068696	total: 4.37s	remaining: 5.79s
# 43:	learn: 0.0064491	total: 4.46s	remaining: 5.68s
# 44:	learn: 0.0060590	total: 4.54s	remaining: 5.55s
# 45:	learn: 0.0059514	total: 4.61s	remaining: 5.41s
# 46:	learn: 0.0057017	total: 4.71s	remaining: 5.32s
# 47:	learn: 0.0055218	total: 4.79s	remaining: 5.19s
# 48:	learn: 0.0053308	total: 4.86s	remaining: 5.06s
# 49:	learn: 0.0052439	total: 4.99s	remaining: 4.99s
# 50:	learn: 0.0050239	total: 5.09s	remaining: 4.89s
# 51:	learn: 0.0049135	total: 5.18s	remaining: 4.78s
# 52:	learn: 0.0047334	total: 5.27s	remaining: 4.68s
# 53:	learn: 0.0046508	total: 5.41s	remaining: 4.61s
# 54:	learn: 0.0045663	total: 5.52s	remaining: 4.52s
# 55:	learn: 0.0044032	total: 5.6s	remaining: 4.4s
# 56:	learn: 0.0043060	total: 5.7s	remaining: 4.3s
# 57:	learn: 0.0042052	total: 5.8s	remaining: 4.2s
# 58:	learn: 0.0040567	total: 5.87s	remaining: 4.08s
# 59:	learn: 0.0038806	total: 5.96s	remaining: 3.98s
# 60:	learn: 0.0037970	total: 6.09s	remaining: 3.89s
# 61:	learn: 0.0036746	total: 6.17s	remaining: 3.78s
# 62:	learn: 0.0035692	total: 6.24s	remaining: 3.67s
# 63:	learn: 0.0034609	total: 6.34s	remaining: 3.57s
# 64:	learn: 0.0032822	total: 6.42s	remaining: 3.45s
# 65:	learn: 0.0031972	total: 6.49s	remaining: 3.34s
# 66:	learn: 0.0030293	total: 6.58s	remaining: 3.24s
# 67:	learn: 0.0029383	total: 6.66s	remaining: 3.13s
# 68:	learn: 0.0028645	total: 6.72s	remaining: 3.02s
# 69:	learn: 0.0027916	total: 6.79s	remaining: 2.91s
# 70:	learn: 0.0027584	total: 6.86s	remaining: 2.8s
# 71:	learn: 0.0027165	total: 6.92s	remaining: 2.69s
# 72:	learn: 0.0026601	total: 7.02s	remaining: 2.6s
# 73:	learn: 0.0025173	total: 7.12s	remaining: 2.5s
# 74:	learn: 0.0024212	total: 7.19s	remaining: 2.4s
# 75:	learn: 0.0023743	total: 7.25s	remaining: 2.29s
# 76:	learn: 0.0023412	total: 7.35s	remaining: 2.19s
# 77:	learn: 0.0023047	total: 7.42s	remaining: 2.09s
# 78:	learn: 0.0022292	total: 7.49s	remaining: 1.99s
# 79:	learn: 0.0021809	total: 7.57s	remaining: 1.89s
# 80:	learn: 0.0021404	total: 7.64s	remaining: 1.79s
# 81:	learn: 0.0020881	total: 7.71s	remaining: 1.69s
# 82:	learn: 0.0020605	total: 7.77s	remaining: 1.59s
# 83:	learn: 0.0020008	total: 7.83s	remaining: 1.49s
# 84:	learn: 0.0019691	total: 7.89s	remaining: 1.39s
# 85:	learn: 0.0019093	total: 7.98s	remaining: 1.3s
# 86:	learn: 0.0018868	total: 8.06s	remaining: 1.2s
# 87:	learn: 0.0018644	total: 8.11s	remaining: 1.1s
# 88:	learn: 0.0018394	total: 8.16s	remaining: 1.01s
# 89:	learn: 0.0018238	total: 8.26s	remaining: 918ms
# 90:	learn: 0.0018166	total: 8.32s	remaining: 823ms
# 91:	learn: 0.0017917	total: 8.37s	remaining: 728ms
# 92:	learn: 0.0017576	total: 8.42s	remaining: 634ms
# 93:	learn: 0.0017260	total: 8.52s	remaining: 544ms
# 94:	learn: 0.0016862	total: 8.62s	remaining: 454ms
# 95:	learn: 0.0016723	total: 8.7s	remaining: 362ms
# 96:	learn: 0.0016599	total: 8.77s	remaining: 271ms
# 97:	learn: 0.0016143	total: 8.87s	remaining: 181ms
# 98:	learn: 0.0015979	total: 8.92s	remaining: 90.1ms
# 99:	learn: 0.0015845	total: 9.01s	remaining: 0us
# <style  type="text/css" >
# #T_4b608d80_b100_11ec_af1c_48a472d2776erow0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.3%, transparent 83.3%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.2%, transparent 82.2%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.9%, transparent 82.9%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow1_col2,#T_4b608d80_b100_11ec_af1c_48a472d2776erow2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.5%, transparent 81.5%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.9%, transparent 80.9%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.1%, transparent 81.1%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.9%, transparent 79.9%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.5%, transparent 79.5%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.2%, transparent 79.2%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 77.9%, transparent 77.9%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 77.1%, transparent 77.1%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 75.9%, transparent 75.9%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 74.8%, transparent 74.8%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 75.6%, transparent 75.6%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 74.0%, transparent 74.0%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 75.2%, transparent 75.2%);
#         }#T_4b608d80_b100_11ec_af1c_48a472d2776erow8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 74.2%, transparent 74.2%);
#         }</style><table id="T_4b608d80_b100_11ec_af1c_48a472d2776e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4b608d80_b100_11ec_af1c_48a472d2776elevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow0_col0" class="data row0 col0" >Skl HistGBM</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow0_col1" class="data row0 col1" >83.261538</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow0_col2" class="data row0 col2" >82.207678</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow0_col3" class="data row0 col3" >10.582390</td>
#             </tr>
#             <tr>
#                         <th id="T_4b608d80_b100_11ec_af1c_48a472d2776elevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow1_col0" class="data row1 col0" >XGBoost</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow1_col1" class="data row1 col1" >82.903846</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow1_col2" class="data row1 col2" >81.546954</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow1_col3" class="data row1 col3" >19.259091</td>
#             </tr>
#             <tr>
#                         <th id="T_4b608d80_b100_11ec_af1c_48a472d2776elevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow2_col0" class="data row2 col0" >LightGBM</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow2_col1" class="data row2 col1" >81.523077</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow2_col2" class="data row2 col2" >80.851331</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow2_col3" class="data row2 col3" >4.886788</td>
#             </tr>
#             <tr>
#                         <th id="T_4b608d80_b100_11ec_af1c_48a472d2776elevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow3_col0" class="data row3 col0" >Random Forest</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow3_col1" class="data row3 col1" >81.130769</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow3_col2" class="data row3 col2" >79.874647</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow3_col3" class="data row3 col3" >11.114382</td>
#             </tr>
#             <tr>
#                         <th id="T_4b608d80_b100_11ec_af1c_48a472d2776elevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow4_col0" class="data row4 col0" >Skl GBM</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow4_col1" class="data row4 col1" >79.519231</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow4_col2" class="data row4 col2" >79.230926</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow4_col3" class="data row4 col3" >187.350111</td>
#             </tr>
#             <tr>
#                         <th id="T_4b608d80_b100_11ec_af1c_48a472d2776elevel0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow5_col0" class="data row5 col0" >CatBoost</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow5_col1" class="data row5 col1" >77.873077</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow5_col2" class="data row5 col2" >77.105340</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow5_col3" class="data row5 col3" >11.000095</td>
#             </tr>
#             <tr>
#                         <th id="T_4b608d80_b100_11ec_af1c_48a472d2776elevel0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow6_col0" class="data row6 col0" >AdaBoost</td>
#                         <td id="T_4b608d80_b100_11ec_af1c_48a472d2776erow6_col1" class="data row6 col1" >75.930769</td>
#                         <td id="T_4b608d80_b100_11ec
