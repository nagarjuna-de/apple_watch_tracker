# %%
import time
from IPython.display import clear_output
import numpy    as np
import pandas   as pd
import seaborn  as sns
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
import sklearn  as skl
from numpy import asarray

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline      
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config

set_config(display='diagram') # Useful for display the pipeline
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
from sklearn.svm           import SVC

# %%
data = pd.read_csv(r'C:\Users\rnr31\Documents\GitHub\apple_watch_tracker\Datasets\dataset_0.5sec.csv')

# %%
oe = OrdinalEncoder()
ct = asarray(data['user'])
data['user'] = oe.fit_transform(ct.reshape(-1,1))
data = data.sort_values(by='user')
data
# Out:
#        Unnamed: 0      id    time  activityrecognition#0  \
# 62584       62584   84508   630.0                    NaN
# 21106       21106    8609   234.0                    NaN
# 21105       21105   22422  1727.0                    NaN
# 21104       21104   11240  1151.0                    NaN
# 21103       21103    7828   289.0                    NaN
# ...           ...     ...     ...                    ...
# 37690       37690  129745   309.0                    NaN
# 37689       37689  129760   324.0                    NaN
# 37688       37688  131014  1578.0                    NaN
# 37699       37699  130782  1346.0                    NaN
# 52624       52624  131097    74.0                    NaN
#
#        activityrecognition#1  android.sensor.accelerometer#mean  \
# 62584                  100.0                          15.892297
# 21106                  100.0                          10.142241
# 21105                    8.0                          10.033811
# 21104                  100.0                          10.044192
# 21103                   85.0                           8.514446
# ...                      ...                                ...
# 37690                    8.0                          10.805771
# 37689                    8.0                          10.389200
# 37688                    8.0                          10.718977
# 37699                    8.0                          10.551876
# 52624                  100.0                           7.831070
#
#        android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 62584                         15.892297                         15.892297
# 21106                         10.142241                         10.142241
# 21105                          9.701954                         10.334343
# 21104                          9.843447                         10.144604
# 21103                          8.514446                          8.514446
# ...                                 ...                               ...
# 37690                         10.805771                         10.805771
# 37689                         10.389200                         10.389200
# 37688                         10.704910                         10.733045
# 37699                         10.463580                         10.686567
# 52624                          4.649800                         11.012339
#
#        android.sensor.accelerometer#std  \
# 62584                          3.606631
# 21106                          0.007413
# 21105                          0.317356
# 21104                          0.173851
# 21103                          0.062750
# ...                                 ...
# 37690                          0.102640
# 37689                          0.019366
# 37688                          0.019895
# 37699                          0.118512
# 52624                          4.498995
#
#        android.sensor.game_rotation_vector#mean  ...  sound#mean  sound#min  \
# 62584                                  0.838142  ...   89.730876  89.730876
# 21106                                  0.840593  ...   89.770732  89.770732
# 21105                                  0.890862  ...   89.794108  89.794108
# 21104                                  0.772161  ...         NaN        NaN
# 21103                                  0.734319  ...   89.738523  89.738523
# ...                                         ...  ...         ...        ...
# 37690                                       NaN  ...   71.595672  71.595672
# 37689                                       NaN  ...   68.089832  68.089832
# 37688                                       NaN  ...   70.312179  70.312179
# 37699                                       NaN  ...   68.048667  68.048667
# 52624                                       NaN  ...   72.281062  72.281062
#
#        sound#max  sound#std  speed#mean  speed#min  speed#max  speed#std  \
# 62584  89.730876        NaN        0.75       0.75       0.75        NaN
# 21106  89.770732        NaN       13.50      13.50      13.50        NaN
# 21105  89.794108        NaN       20.50      20.50      20.50        NaN
# 21104        NaN        NaN       32.50      32.50      32.50        NaN
# 21103  89.738523        NaN       12.25      12.25      12.25        NaN
# ...          ...        ...         ...        ...        ...        ...
# 37690  71.595672        NaN         NaN        NaN        NaN        NaN
# 37689  68.089832        NaN         NaN        NaN        NaN        NaN
# 37688  70.312179        NaN         NaN        NaN        NaN        NaN
# 37699  68.048667        NaN         NaN        NaN        NaN        NaN
# 52624  72.281062        NaN         NaN        NaN        NaN        NaN
#
#         target  user
# 62584  Walking   0.0
# 21106      Car   0.0
# 21105      Car   0.0
# 21104      Car   0.0
# 21103      Car   0.0
# ...        ...   ...
# 37690    Train  12.0
# 37689    Train  12.0
# 37688    Train  12.0
# 37699    Train  12.0
# 52624  Walking  12.0
#
# [62585 rows x 71 columns]

# %%
def col_names_change(data):
    data.drop(['Unnamed: 0','id', 'activityrecognition#0'],axis=1, inplace=True)
    data_col = ['time','activityrecognition_1']
    for i in data.columns[2:58]:
        b = i.split('.')[2].split('#')
        data_col.append(f'{b[0]}_{b[1]}')

    for i in data.columns[58:66]:
        b = i.split('#')
        data_col.append(f'{b[0]}_{b[1]}')

    data_col.append('target')
    data_col.append('user')
    data = pd.DataFrame.from_records(data.values)
    data.columns = data_col

    return data

# %%
data = col_names_change(data)

# %%
data.drop(['pressure_mean', 'pressure_max', 'pressure_min', 'pressure_std', 'sound_std', 'speed_std','step_counter_mean','step_counter_std','light_std',
            'proximity_mean','proximity_min','proximity_max','proximity_std', 'step_counter_min', 'step_counter_max' ], axis=1, inplace=True)

# %%
data['target']= data['target'].apply({'Bus':0, 'Car':1, 'Still':2, 'Train':3, 'Walking':4}.get)

# %%
df0 = data[data['target']==0]
df1 = data[data['target']==1]
df2 = data[data['target']==2]
df3 = data[data['target']==3]
df4 = data[data['target']==4]
#msno.matrix(df1)

# %%
def fill_nan_values(tsdf):
    for i in tsdf.columns:
        ndf = tsdf.groupby(['target'])[f'{i}'].mean()
        mn = ndf.values[0]
        tsdf[f'{i}'] = tsdf[f'{i}'].fillna(mn)
    return tsdf

df0 = fill_nan_values(df0)
df1 = fill_nan_values(df1)
df2 = fill_nan_values(df2)
df3 = fill_nan_values(df3)
df4 = fill_nan_values(df4)
# Out:
# C:\Users\rnr31\AppData\Local\Temp\ipykernel_17152\154742137.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tsdf[f'{i}'] = tsdf[f'{i}'].fillna(mn)

# %%
data = pd.concat([df0, df1, df2, df3, df4])
data.shape
# Out:
# (62585, 53)

# %%
data
# Out:
#         time  activityrecognition_1  accelerometer_mean  accelerometer_min  \
# 13713  821.0                  100.0            9.580663           9.580663
# 13714   13.0                  100.0           10.958598           9.868953
# 13715   12.0                  100.0           10.958598           9.868953
# 13716   11.0                  100.0            8.841528           6.835641
# 13717   10.0                  100.0           11.618934           9.715548
# ...      ...                    ...                 ...                ...
# 62145  483.0                  100.0           10.265969           8.937641
# 62146  418.0                  100.0           14.321415          14.321415
# 62147  546.0                  100.0           25.482379          25.482379
# 62529  854.0                   85.0           13.730206          13.730206
# 62584   74.0                  100.0            7.831070           4.649800
#
#        accelerometer_max  accelerometer_std  game_rotation_vector_mean  \
# 13713           9.580663           0.012232                   0.801618
# 13714          12.048243           1.540991                   0.779063
# 13715          12.048243           1.540991                   0.779063
# 13716          10.847415           2.836753                   0.779063
# 13717          13.385976           1.839009                   0.779063
# ...                  ...                ...                        ...
# 62145          11.594297           1.878540                   0.870339
# 62146          14.321415           3.729311                   0.870339
# 62147          25.482379           1.884572                   0.870339
# 62529          13.730206           1.836736                   0.870339
# 62584          11.012339           4.498995                   0.870339
#
#        game_rotation_vector_min  game_rotation_vector_max  \
# 13713                  0.801618                  0.801618
# 13714                  0.779063                  0.779063
# 13715                  0.779063                  0.779063
# 13716                  0.779063                  0.779063
# 13717                  0.779063                  0.779063
# ...                         ...                       ...
# 62145                  0.862206                  0.876766
# 62146                  0.862206                  0.876766
# 62147                  0.862206                  0.876766
# 62529                  0.862206                  0.876766
# 62584                  0.862206                  0.876766
#
#        game_rotation_vector_std  ...  rotation_vector_max  \
# 13713                  0.000162  ...             0.928278
# 13714                  0.004365  ...             0.482034
# 13715                  0.004365  ...             0.452277
# 13716                  0.004365  ...             0.452277
# 13717                  0.004365  ...             0.417588
# ...                         ...  ...                  ...
# 62145                  0.015529  ...             0.972661
# 62146                  0.015529  ...             0.879428
# 62147                  0.015529  ...             0.854721
# 62529                  0.015529  ...             0.996823
# 62584                  0.015529  ...             0.817068
#
#        rotation_vector_std  sound_mean  sound_min  sound_max  speed_mean  \
# 13713             0.000081   85.121360  85.121360  85.121360    8.000000
# 13714             0.008963   83.843193  83.843144  83.843242    5.341548
# 13715             0.004023   83.843193  83.843144  83.843242    5.341548
# 13716             0.004023   83.843193  83.843144  83.843242    5.341548
# 13717             0.004023   83.843193  83.843144  83.843242    5.341548
# ...                    ...         ...        ...        ...         ...
# 62145             0.016987   73.757710  73.757710  73.757710    1.178197
# 62146             0.004941   79.568839  79.567896  79.569832    1.178197
# 62147             0.029765   79.568839  79.567896  79.569832    1.178197
# 62529             0.001330   78.116997  78.116997  78.116997    1.178197
# 62584             0.033511   72.281062  72.281062  72.281062    1.178197
#
#        speed_min  speed_max  target  user
# 13713   8.000000   8.000000       0   0.0
# 13714   5.341548   5.341548       0   0.0
# 13715   5.341548   5.341548       0   0.0
# 13716   5.341548   5.341548       0   0.0
# 13717   5.341548   5.341548       0   0.0
# ...          ...        ...     ...   ...
# 62145   1.178197   1.178197       4  12.0
# 62146   1.178197   1.178197       4  12.0
# 62147   1.178197   1.178197       4  12.0
# 62529   1.178197   1.178197       4  12.0
# 62584   1.178197   1.178197       4  12.0
#
# [62585 rows x 53 columns]

# %%
data = data.sort_values(by='user')
data.drop(['user'], axis=1, inplace=True)

# %%
accelerometer_min = asarray(data['accelerometer_min'])
accelerometer_max = asarray(data['accelerometer_max'])
gyroscope_uncalibrated_min = asarray(data['gyroscope_uncalibrated_min'])
gyroscope_uncalibrated_max = asarray(data['gyroscope_uncalibrated_max'])
linear_acceleration_min = asarray(data['linear_acceleration_min'])
linear_acceleration_max = asarray(data['linear_acceleration_max'])
######
data = data.drop(data.filter(regex='min').columns, axis=1)
data = data.drop(data.filter(regex='max').columns, axis=1)
#####
data['accelerometer_min'] = accelerometer_min 
data['accelerometer_max'] = accelerometer_max
data['gyroscope_uncalibrated_min'] = gyroscope_uncalibrated_min
data['gyroscope_uncalibrated_max'] = gyroscope_uncalibrated_max
data['linear_acceleration_min'] = linear_acceleration_min
data['linear_acceleration_max'] = linear_acceleration_max
data
# Out:
#          time  activityrecognition_1  accelerometer_mean  accelerometer_std  \
# 13713   821.0                  100.0            9.580663           0.012232
# 13104    31.0                  100.0            9.645943           0.206842
# 13105  1381.0                  100.0            9.697037           0.033686
# 13106   599.0                  100.0           10.062870           0.067896
# 13107  2728.0                   15.0           10.172925           0.026775
# ...       ...                    ...                 ...                ...
# 62289  1121.0                    8.0           10.652345           0.145613
# 62288  1079.0                    8.0           10.622010           0.069927
# 62287   755.0                    8.0           10.514805           0.303703
# 62298   601.0                    8.0           10.473649           0.065375
# 62584    74.0                  100.0            7.831070           4.498995
#
#        game_rotation_vector_mean  game_rotation_vector_std  gravity_mean  \
# 13713                   0.801618              1.617893e-04      9.806650
# 13104                   0.739330              7.427495e-03      9.806650
# 13105                   0.986589              4.705820e-06      9.806650
# 13106                   0.966962              1.132248e-04      9.806650
# 13107                   0.990579              4.727893e-07      9.806651
# ...                          ...                       ...           ...
# 62289                   0.762776              1.539067e-03      9.806650
# 62288                   0.762776              1.539067e-03      9.806651
# 62287                   0.762776              1.539067e-03      9.806650
# 62298                   0.762776              1.539067e-03      9.806650
# 62584                   0.870339              1.552893e-02      9.806649
#
#         gravity_std  gyroscope_mean  gyroscope_std  ...  rotation_vector_std  \
# 13713  5.216953e-07        0.037269       0.016188  ...             0.000081
# 13104  4.209336e-07        0.248027       0.034275  ...             0.002077
# 13105  1.079752e-08        0.004636       0.005330  ...             0.000032
# 13106  7.184205e-08        0.023576       0.015889  ...             0.000323
# 13107  4.146969e-07        0.004143       0.001013  ...             0.000014
# ...             ...             ...            ...  ...                  ...
# 62289  3.715563e-07        0.077557       0.003418  ...             0.000095
# 62288  2.531796e-07        0.070117       0.003679  ...             0.000070
# 62287  2.803891e-07        0.069321       0.020483  ...             0.000299
# 62298  4.575759e-07        0.094089       0.015840  ...             0.000472
# 62584  3.063583e-04        3.001325       1.447075  ...             0.033511
#
#        sound_mean  speed_mean  target  accelerometer_min  accelerometer_max  \
# 13713   85.121360    8.000000       0           9.580663           9.580663
# 13104   85.603369   33.705530       3           9.645943           9.645943
# 13105   88.017664   33.705530       3           9.697037           9.697037
# 13106   89.756620   33.705530       3          10.014861          10.110879
# 13107   78.007343   33.705530       3          10.172925          10.172925
# ...           ...         ...     ...                ...                ...
# 62289   51.174171   33.705530       3          10.441941          10.777754
# 62288   50.343918   33.705530       3          10.622010          10.622010
# 62287   74.830910   33.705530       3          10.168924          10.737847
# 62298   70.472328   33.705530       3          10.473649          10.473649
# 62584   72.281062    1.178197       4           4.649800          11.012339
#
#        gyroscope_uncalibrated_min  gyroscope_uncalibrated_max  \
# 13713                    0.036633                    0.036633
# 13104                    0.220782                    0.220782
# 13105                    0.031598                    0.031598
# 13106                    0.032029                    0.032029
# 13107                    0.036818                    0.036818
# ...                           ...                         ...
# 62289                    0.063161                    0.086416
# 62288                    0.063161                    0.086416
# 62287                    0.063161                    0.086416
# 62298                    0.063161                    0.086416
# 62584                    0.996082                    1.434283
#
#        linear_acceleration_min  linear_acceleration_max
# 13713                 0.067885                 0.067885
# 13104                 0.237493                 0.237493
# 13105                 0.060151                 0.060151
# 13106                 0.051883                 0.051883
# 13107                 0.022213                 0.022213
# ...                        ...                      ...
# 62289                 0.702425                 0.702425
# 62288                 0.842117                 0.842117
# 62287                 0.654386                 0.654386
# 62298                 0.841839                 0.841839
# 62584                 3.094950                 3.094950
#
# [62585 rows x 32 columns]

# %%
data_test = data.iloc[:26000, :]
data_train = data.iloc[26000: , :]

#### Training sets
x_train = data_train.drop(['target'], axis=1)
y_train = data_train['target']

#### Testing sets
x_test = data_test.drop(['target'], axis=1)
y_test = data_test['target']

# %%
y_train.unique()
# Out:
# array([2, 4, 1, 0, 3], dtype=int64)

# %%
y_test.unique()
# Out:
# array([0, 3, 1, 2, 4], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler = scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
tree_classifiers = {
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees": ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost": AdaBoostClassifier(n_estimators=100),
  "Skl GBM": GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM": HistGradientBoostingClassifier(max_iter=100),
  "XGBoost": XGBClassifier(n_estimators=100),
  "LightGBM": LGBMClassifier(n_estimators=100),
  "CatBoost":  CatBoostClassifier(n_estimators=100),
}

# %%
tree_classifiers = {name: make_pipeline(model) for name, model in tree_classifiers.items()}

results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

# %%
rang = abs(y_train.max()) + abs(y_train.min())
for model_name, model in tree_classifiers.items():
    
    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time() - start_time
        
    pred = model.predict(x_test)
    
    results = results.append({"Model":    model_name,
                              "Accuracy": accuracy_score(y_test, pred)*100,
                              "Bal Acc.": balanced_accuracy_score(y_test, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:59:03] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.5
# 0:	learn: 0.5997296	total: 212ms	remaining: 20.9s
# 1:	learn: 0.4267634	total: 307ms	remaining: 15s
# 2:	learn: 0.3166561	total: 394ms	remaining: 12.7s
# 3:	learn: 0.2335244	total: 465ms	remaining: 11.2s
# 4:	learn: 0.1891897	total: 549ms	remaining: 10.4s
# 5:	learn: 0.1554994	total: 612ms	remaining: 9.59s
# 6:	learn: 0.1302786	total: 688ms	remaining: 9.13s
# 7:	learn: 0.1120050	total: 751ms	remaining: 8.63s
# 8:	learn: 0.0978527	total: 832ms	remaining: 8.42s
# 9:	learn: 0.0828767	total: 902ms	remaining: 8.12s
# 10:	learn: 0.0747000	total: 967ms	remaining: 7.83s
# 11:	learn: 0.0663789	total: 1.03s	remaining: 7.56s
# 12:	learn: 0.0565943	total: 1.1s	remaining: 7.35s
# 13:	learn: 0.0511370	total: 1.16s	remaining: 7.15s
# 14:	learn: 0.0441446	total: 1.25s	remaining: 7.11s
# 15:	learn: 0.0415721	total: 1.33s	remaining: 6.99s
# 16:	learn: 0.0380231	total: 1.39s	remaining: 6.78s
# 17:	learn: 0.0346470	total: 1.45s	remaining: 6.62s
# 18:	learn: 0.0306731	total: 1.52s	remaining: 6.5s
# 19:	learn: 0.0282427	total: 1.6s	remaining: 6.42s
# 20:	learn: 0.0265643	total: 1.67s	remaining: 6.27s
# 21:	learn: 0.0232488	total: 1.74s	remaining: 6.17s
# 22:	learn: 0.0216053	total: 1.81s	remaining: 6.05s
# 23:	learn: 0.0198880	total: 1.88s	remaining: 5.95s
# 24:	learn: 0.0183223	total: 1.96s	remaining: 5.89s
# 25:	learn: 0.0171052	total: 2.04s	remaining: 5.81s
# 26:	learn: 0.0167129	total: 2.1s	remaining: 5.68s
# 27:	learn: 0.0150526	total: 2.16s	remaining: 5.56s
# 28:	learn: 0.0137763	total: 2.23s	remaining: 5.46s
# 29:	learn: 0.0123550	total: 2.3s	remaining: 5.37s
# 30:	learn: 0.0119045	total: 2.37s	remaining: 5.28s
# 31:	learn: 0.0116630	total: 2.45s	remaining: 5.21s
# 32:	learn: 0.0113572	total: 2.51s	remaining: 5.1s
# 33:	learn: 0.0107164	total: 2.57s	remaining: 5s
# 34:	learn: 0.0101712	total: 2.65s	remaining: 4.92s
# 35:	learn: 0.0099045	total: 2.73s	remaining: 4.85s
# 36:	learn: 0.0092758	total: 2.78s	remaining: 4.74s
# 37:	learn: 0.0091386	total: 2.85s	remaining: 4.66s
# 38:	learn: 0.0089054	total: 2.92s	remaining: 4.57s
# 39:	learn: 0.0082421	total: 2.98s	remaining: 4.47s
# 40:	learn: 0.0079560	total: 3.06s	remaining: 4.4s
# 41:	learn: 0.0075638	total: 3.15s	remaining: 4.34s
# 42:	learn: 0.0069719	total: 3.22s	remaining: 4.27s
# 43:	learn: 0.0067307	total: 3.29s	remaining: 4.19s
# 44:	learn: 0.0065989	total: 3.36s	remaining: 4.1s
# 45:	learn: 0.0063266	total: 3.41s	remaining: 4s
# 46:	learn: 0.0062405	total: 3.49s	remaining: 3.94s
# 47:	learn: 0.0060567	total: 3.57s	remaining: 3.87s
# 48:	learn: 0.0056373	total: 3.65s	remaining: 3.8s
# 49:	learn: 0.0055221	total: 3.73s	remaining: 3.73s
# 50:	learn: 0.0053493	total: 3.79s	remaining: 3.64s
# 51:	learn: 0.0052254	total: 3.88s	remaining: 3.58s
# 52:	learn: 0.0051725	total: 3.95s	remaining: 3.51s
# 53:	learn: 0.0050825	total: 4.01s	remaining: 3.42s
# 54:	learn: 0.0048861	total: 4.08s	remaining: 3.34s
# 55:	learn: 0.0047225	total: 4.15s	remaining: 3.26s
# 56:	learn: 0.0045108	total: 4.23s	remaining: 3.19s
# 57:	learn: 0.0044264	total: 4.32s	remaining: 3.13s
# 58:	learn: 0.0042868	total: 4.39s	remaining: 3.05s
# 59:	learn: 0.0041667	total: 4.45s	remaining: 2.97s
# 60:	learn: 0.0040474	total: 4.52s	remaining: 2.89s
# 61:	learn: 0.0039309	total: 4.59s	remaining: 2.81s
# 62:	learn: 0.0038495	total: 4.65s	remaining: 2.73s
# 63:	learn: 0.0036377	total: 4.73s	remaining: 2.66s
# 64:	learn: 0.0036122	total: 4.76s	remaining: 2.56s
# 65:	learn: 0.0035547	total: 4.79s	remaining: 2.47s
# 66:	learn: 0.0034304	total: 4.83s	remaining: 2.38s
# 67:	learn: 0.0033999	total: 4.87s	remaining: 2.29s
# 68:	learn: 0.0033127	total: 4.92s	remaining: 2.21s
# 69:	learn: 0.0030769	total: 4.99s	remaining: 2.14s
# 70:	learn: 0.0030110	total: 5.07s	remaining: 2.07s
# 71:	learn: 0.0029025	total: 5.11s	remaining: 1.99s
# 72:	learn: 0.0028671	total: 5.17s	remaining: 1.91s
# 73:	learn: 0.0027781	total: 5.22s	remaining: 1.83s
# 74:	learn: 0.0026986	total: 5.27s	remaining: 1.76s
# 75:	learn: 0.0026584	total: 5.35s	remaining: 1.69s
# 76:	learn: 0.0025756	total: 5.41s	remaining: 1.62s
# 77:	learn: 0.0025533	total: 5.46s	remaining: 1.54s
# 78:	learn: 0.0025428	total: 5.66s	remaining: 1.5s
# 79:	learn: 0.0025005	total: 5.88s	remaining: 1.47s
# 80:	learn: 0.0024559	total: 5.92s	remaining: 1.39s
# 81:	learn: 0.0024306	total: 5.95s	remaining: 1.31s
# 82:	learn: 0.0024156	total: 5.99s	remaining: 1.23s
# 83:	learn: 0.0023338	total: 6.04s	remaining: 1.15s
# 84:	learn: 0.0022931	total: 6.12s	remaining: 1.08s
# 85:	learn: 0.0022531	total: 6.17s	remaining: 1s
# 86:	learn: 0.0021704	total: 6.23s	remaining: 932ms
# 87:	learn: 0.0021456	total: 6.3s	remaining: 860ms
# 88:	learn: 0.0021002	total: 6.38s	remaining: 789ms
# 89:	learn: 0.0020834	total: 6.45s	remaining: 717ms
# 90:	learn: 0.0020530	total: 6.5s	remaining: 643ms
# 91:	learn: 0.0019914	total: 6.57s	remaining: 571ms
# 92:	learn: 0.0019201	total: 6.63s	remaining: 499ms
# 93:	learn: 0.0019028	total: 6.69s	remaining: 427ms
# 94:	learn: 0.0018340	total: 6.79s	remaining: 358ms
# 95:	learn: 0.0018055	total: 6.86s	remaining: 286ms
# 96:	learn: 0.0017654	total: 6.95s	remaining: 215ms
# 97:	learn: 0.0016846	total: 7.03s	remaining: 144ms
# 98:	learn: 0.0016756	total: 7.07s	remaining: 71.4ms
# 99:	learn: 0.0016570	total: 7.1s	remaining: 0us
# <style  type="text/css" >
# #T_4f21ff02_b11c_11ec_bee7_48a472d2776erow0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.9%, transparent 81.9%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.7%, transparent 80.7%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.4%, transparent 81.4%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.4%, transparent 80.4%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.0%, transparent 81.0%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.9%, transparent 79.9%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.8%, transparent 80.8%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.3%, transparent 80.3%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.3%, transparent 79.3%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.1%, transparent 79.1%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 75.2%, transparent 75.2%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 75.0%, transparent 75.0%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 74.4%, transparent 74.4%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 74.2%, transparent 74.2%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 65.0%, transparent 65.0%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 63.0%, transparent 63.0%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 62.3%, transparent 62.3%);
#         }#T_4f21ff02_b11c_11ec_bee7_48a472d2776erow8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 65.9%, transparent 65.9%);
#         }</style><table id="T_4f21ff02_b11c_11ec_bee7_48a472d2776e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4f21ff02_b11c_11ec_bee7_48a472d2776elevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow0_col0" class="data row0 col0" >Skl HistGBM</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow0_col1" class="data row0 col1" >81.934615</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow0_col2" class="data row0 col2" >80.736346</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow0_col3" class="data row0 col3" >7.650633</td>
#             </tr>
#             <tr>
#                         <th id="T_4f21ff02_b11c_11ec_bee7_48a472d2776elevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow1_col0" class="data row1 col0" >XGBoost</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow1_col1" class="data row1 col1" >81.415385</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow1_col2" class="data row1 col2" >80.430413</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow1_col3" class="data row1 col3" >13.201927</td>
#             </tr>
#             <tr>
#                         <th id="T_4f21ff02_b11c_11ec_bee7_48a472d2776elevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow2_col0" class="data row2 col0" >CatBoost</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow2_col1" class="data row2 col1" >80.965385</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow2_col2" class="data row2 col2" >79.852103</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow2_col3" class="data row2 col3" >7.777796</td>
#             </tr>
#             <tr>
#                         <th id="T_4f21ff02_b11c_11ec_bee7_48a472d2776elevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow3_col0" class="data row3 col0" >LightGBM</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow3_col1" class="data row3 col1" >80.819231</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow3_col2" class="data row3 col2" >80.251214</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow3_col3" class="data row3 col3" >3.004132</td>
#             </tr>
#             <tr>
#                         <th id="T_4f21ff02_b11c_11ec_bee7_48a472d2776elevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow4_col0" class="data row4 col0" >Skl GBM</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow4_col1" class="data row4 col1" >79.276923</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow4_col2" class="data row4 col2" >79.129775</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow4_col3" class="data row4 col3" >127.727377</td>
#             </tr>
#             <tr>
#                         <th id="T_4f21ff02_b11c_11ec_bee7_48a472d2776elevel0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow5_col0" class="data row5 col0" >Random Forest</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow5_col1" class="data row5 col1" >75.188462</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow5_col2" class="data row5 col2" >75.014517</td>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow5_col3" class="data row5 col3" >10.420161</td>
#             </tr>
#             <tr>
#                         <th id="T_4f21ff02_b11c_11ec_bee7_48a472d2776elevel0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_4f21ff02_b11c_11ec_bee7_48a472d2776erow6_col0" class="data row6 col0" >Extra Trees</td>
#                         <t
