# %%
import time
from IPython.display import clear_output
import numpy    as np
import pandas   as pd
import seaborn  as sns
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
import sklearn  as skl
from numpy import asarray

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline      
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config

set_config(display='diagram') # Useful for display the pipeline
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
from sklearn.svm           import SVC

# %%
data = pd.read_csv(r'C:\Users\rnr31\Documents\GitHub\apple_watch_tracker\Datasets\dataset_0.5sec.csv')
data
# Out:
#        Unnamed: 0      id    time  activityrecognition#0  \
# 0               0  156661     3.0                    NaN
# 1               1  156662     4.0                    NaN
# 2               2  156663     5.0                    NaN
# 3               3  156664     6.0                    NaN
# 4               4  156665     7.0                    NaN
# ...           ...     ...     ...                    ...
# 62580       62580   82695  4066.0                    NaN
# 62581       62581   77608   604.0                    NaN
# 62582       62582   85219  1341.0                    NaN
# 62583       62583   69368  1186.0                    NaN
# 62584       62584   84508   630.0                    NaN
#
#        activityrecognition#1  android.sensor.accelerometer#mean  \
# 0                       62.0                          10.053802
# 1                       62.0                          10.687402
# 2                       62.0                          11.816800
# 3                       62.0                           9.401312
# 4                       62.0                          10.389851
# ...                      ...                                ...
# 62580                   51.0                          10.105329
# 62581                  100.0                           9.544118
# 62582                  100.0                          14.258467
# 62583                   90.0                          10.726491
# 62584                  100.0                          15.892297
#
#        android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 0                              4.328630                         14.419712
# 1                              6.373194                         16.329818
# 2                              4.817410                         16.854629
# 3                              6.124588                         12.230792
# 4                              5.313790                         38.533453
# ...                                 ...                               ...
# 62580                         10.089159                         10.135641
# 62581                          9.544118                          9.544118
# 62582                         14.258467                         14.258467
# 62583                         10.726491                         10.726491
# 62584                         15.892297                         15.892297
#
#        android.sensor.accelerometer#std  \
# 0                              2.359507
# 1                              2.912315
# 2                              3.199759
# 3                              1.572354
# 4                              5.426978
# ...                                 ...
# 62580                          0.026270
# 62581                         14.491194
# 62582                          0.829544
# 62583                          7.089701
# 62584                          3.606631
#
#        android.sensor.game_rotation_vector#mean  ...  sound#mean  sound#min  \
# 0                                      0.629076  ...         NaN        NaN
# 1                                      0.577839  ...         NaN        NaN
# 2                                      0.651511  ...         NaN        NaN
# 3                                      0.713226  ...         NaN        NaN
# 4                                      0.707375  ...         NaN        NaN
# ...                                         ...  ...         ...        ...
# 62580                                  0.834765  ...   89.761985  89.761985
# 62581                                  0.965309  ...   89.747010  89.747010
# 62582                                  0.773370  ...   89.729460  89.729460
# 62583                                  0.789832  ...   89.778343  89.778343
# 62584                                  0.838142  ...   89.730876  89.730876
#
#        sound#max  sound#std  speed#mean  speed#min  speed#max  speed#std  \
# 0            NaN        NaN         NaN        NaN        NaN        NaN
# 1            NaN        NaN         NaN        NaN        NaN        NaN
# 2            NaN        NaN         NaN        NaN        NaN        NaN
# 3            NaN        NaN         NaN        NaN        NaN        NaN
# 4            NaN        NaN         NaN        NaN        NaN        NaN
# ...          ...        ...         ...        ...        ...        ...
# 62580  89.761985        NaN        0.00       0.00       0.00        NaN
# 62581  89.747010        NaN        1.50       1.50       1.50        NaN
# 62582  89.729460        NaN        0.00       0.00       0.00        NaN
# 62583  89.778343        NaN        1.00       1.00       1.00        NaN
# 62584  89.730876        NaN        0.75       0.75       0.75        NaN
#
#         target  user
# 0          Bus   U12
# 1          Bus   U12
# 2          Bus   U12
# 3          Bus   U12
# 4          Bus   U12
# ...        ...   ...
# 62580  Walking    U1
# 62581  Walking    U1
# 62582  Walking    U1
# 62583  Walking    U1
# 62584  Walking    U1
#
# [62585 rows x 71 columns]

# %%
oe = OrdinalEncoder()
ct = asarray(data['user'])
data['user'] = oe.fit_transform(ct.reshape(-1,1))
data = data.sort_values(by='user')
data
# Out:
#        Unnamed: 0      id    time  activityrecognition#0  \
# 62584       62584   84508   630.0                    NaN
# 21106       21106    8609   234.0                    NaN
# 21105       21105   22422  1727.0                    NaN
# 21104       21104   11240  1151.0                    NaN
# 21103       21103    7828   289.0                    NaN
# ...           ...     ...     ...                    ...
# 37690       37690  129745   309.0                    NaN
# 37689       37689  129760   324.0                    NaN
# 37688       37688  131014  1578.0                    NaN
# 37699       37699  130782  1346.0                    NaN
# 52624       52624  131097    74.0                    NaN
#
#        activityrecognition#1  android.sensor.accelerometer#mean  \
# 62584                  100.0                          15.892297
# 21106                  100.0                          10.142241
# 21105                    8.0                          10.033811
# 21104                  100.0                          10.044192
# 21103                   85.0                           8.514446
# ...                      ...                                ...
# 37690                    8.0                          10.805771
# 37689                    8.0                          10.389200
# 37688                    8.0                          10.718977
# 37699                    8.0                          10.551876
# 52624                  100.0                           7.831070
#
#        android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 62584                         15.892297                         15.892297
# 21106                         10.142241                         10.142241
# 21105                          9.701954                         10.334343
# 21104                          9.843447                         10.144604
# 21103                          8.514446                          8.514446
# ...                                 ...                               ...
# 37690                         10.805771                         10.805771
# 37689                         10.389200                         10.389200
# 37688                         10.704910                         10.733045
# 37699                         10.463580                         10.686567
# 52624                          4.649800                         11.012339
#
#        android.sensor.accelerometer#std  \
# 62584                          3.606631
# 21106                          0.007413
# 21105                          0.317356
# 21104                          0.173851
# 21103                          0.062750
# ...                                 ...
# 37690                          0.102640
# 37689                          0.019366
# 37688                          0.019895
# 37699                          0.118512
# 52624                          4.498995
#
#        android.sensor.game_rotation_vector#mean  ...  sound#mean  sound#min  \
# 62584                                  0.838142  ...   89.730876  89.730876
# 21106                                  0.840593  ...   89.770732  89.770732
# 21105                                  0.890862  ...   89.794108  89.794108
# 21104                                  0.772161  ...         NaN        NaN
# 21103                                  0.734319  ...   89.738523  89.738523
# ...                                         ...  ...         ...        ...
# 37690                                       NaN  ...   71.595672  71.595672
# 37689                                       NaN  ...   68.089832  68.089832
# 37688                                       NaN  ...   70.312179  70.312179
# 37699                                       NaN  ...   68.048667  68.048667
# 52624                                       NaN  ...   72.281062  72.281062
#
#        sound#max  sound#std  speed#mean  speed#min  speed#max  speed#std  \
# 62584  89.730876        NaN        0.75       0.75       0.75        NaN
# 21106  89.770732        NaN       13.50      13.50      13.50        NaN
# 21105  89.794108        NaN       20.50      20.50      20.50        NaN
# 21104        NaN        NaN       32.50      32.50      32.50        NaN
# 21103  89.738523        NaN       12.25      12.25      12.25        NaN
# ...          ...        ...         ...        ...        ...        ...
# 37690  71.595672        NaN         NaN        NaN        NaN        NaN
# 37689  68.089832        NaN         NaN        NaN        NaN        NaN
# 37688  70.312179        NaN         NaN        NaN        NaN        NaN
# 37699  68.048667        NaN         NaN        NaN        NaN        NaN
# 52624  72.281062        NaN         NaN        NaN        NaN        NaN
#
#         target  user
# 62584  Walking   0.0
# 21106      Car   0.0
# 21105      Car   0.0
# 21104      Car   0.0
# 21103      Car   0.0
# ...        ...   ...
# 37690    Train  12.0
# 37689    Train  12.0
# 37688    Train  12.0
# 37699    Train  12.0
# 52624  Walking  12.0
#
# [62585 rows x 71 columns]

# %%
def col_names_change(data):
    data.drop(['Unnamed: 0','id', 'activityrecognition#0', 'user'],axis=1, inplace=True)
    data_col = ['time','activityrecognition_1']
    for i in data.columns[2:58]:
        b = i.split('.')[2].split('#')
        data_col.append(f'{b[0]}_{b[1]}')

    for i in data.columns[58:66]:
        b = i.split('#')
        data_col.append(f'{b[0]}_{b[1]}')

    data_col.append('target')
    #data_col.append('user')
    data = pd.DataFrame.from_records(data.values)
    data.columns = data_col

    return data

# %%
data = col_names_change(data)

# %%
data['target']= data['target'].apply({'Bus':0, 'Car':1, 'Still':2, 'Train':3, 'Walking':4}.get)

# %%
#data = data.fillna(0)
#data

# %%
data.drop(['pressure_mean', 'pressure_max', 'pressure_min', 'pressure_std', 'sound_std', 'speed_std','step_counter_mean','step_counter_std','light_std',
            'proximity_mean','proximity_min','proximity_max','proximity_std', 'step_counter_min', 'step_counter_max' ], axis=1, inplace=True)

#data

# %%
data_test = data.iloc[:26000, :]
data_train = data.iloc[26000: , :]

#### Training sets
x_train = data_train.drop(['target'], axis=1)
y_train = data_train['target']

#### Testing sets
x_test = data_test.drop(['target'], axis=1)
y_test = data_test['target']

# %%
from sklearn.impute import KNNImputer
knn = KNNImputer(n_neighbors=3)
knn = knn.fit(x_train)
x_train = knn.transform(x_train)
x_test = knn.transform(x_test)

# %%
tree_classifiers = {
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees": ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost": AdaBoostClassifier(n_estimators=100),
  "Skl GBM": GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM": HistGradientBoostingClassifier(max_iter=100),
  "XGBoost": XGBClassifier(n_estimators=100),
  "LightGBM": LGBMClassifier(n_estimators=100),
  "CatBoost":  CatBoostClassifier(n_estimators=100),
}

# %%
tree_classifiers = {name: make_pipeline(model) for name, model in tree_classifiers.items()}

results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

# %%
rang = abs(y_train.max()) + abs(y_train.min())
for model_name, model in tree_classifiers.items():
    
    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time() - start_time
        
    pred = model.predict(x_test)
    
    results = results.append({"Model":    model_name,
                              "Accuracy": accuracy_score(y_test, pred)*100,
                              "Bal Acc.": balanced_accuracy_score(y_test, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [09:12:04] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.5
# 0:	learn: 1.0298782	total: 734ms	remaining: 1m 12s
# 1:	learn: 0.8067408	total: 808ms	remaining: 39.6s
# 2:	learn: 0.6596421	total: 866ms	remaining: 28s
# 3:	learn: 0.5915376	total: 926ms	remaining: 22.2s
# 4:	learn: 0.5199742	total: 978ms	remaining: 18.6s
# 5:	learn: 0.4701021	total: 1.04s	remaining: 16.2s
# 6:	learn: 0.4319284	total: 1.1s	remaining: 14.6s
# 7:	learn: 0.4002304	total: 1.15s	remaining: 13.2s
# 8:	learn: 0.3643188	total: 1.21s	remaining: 12.2s
# 9:	learn: 0.3369417	total: 1.27s	remaining: 11.4s
# 10:	learn: 0.3115698	total: 1.33s	remaining: 10.8s
# 11:	learn: 0.2945391	total: 1.4s	remaining: 10.3s
# 12:	learn: 0.2763823	total: 1.45s	remaining: 9.73s
# 13:	learn: 0.2692147	total: 1.52s	remaining: 9.33s
# 14:	learn: 0.2554419	total: 1.59s	remaining: 9s
# 15:	learn: 0.2470152	total: 1.64s	remaining: 8.62s
# 16:	learn: 0.2371249	total: 1.7s	remaining: 8.3s
# 17:	learn: 0.2288583	total: 1.76s	remaining: 8.02s
# 18:	learn: 0.2161686	total: 1.82s	remaining: 7.77s
# 19:	learn: 0.2099436	total: 1.89s	remaining: 7.55s
# 20:	learn: 0.2044968	total: 1.95s	remaining: 7.33s
# 21:	learn: 0.1932285	total: 2.02s	remaining: 7.17s
# 22:	learn: 0.1862030	total: 2.08s	remaining: 6.98s
# 23:	learn: 0.1809497	total: 2.13s	remaining: 6.76s
# 24:	learn: 0.1729478	total: 2.19s	remaining: 6.58s
# 25:	learn: 0.1671894	total: 2.25s	remaining: 6.41s
# 26:	learn: 0.1611144	total: 2.33s	remaining: 6.29s
# 27:	learn: 0.1570199	total: 2.39s	remaining: 6.15s
# 28:	learn: 0.1542644	total: 2.45s	remaining: 5.99s
# 29:	learn: 0.1518616	total: 2.5s	remaining: 5.83s
# 30:	learn: 0.1495561	total: 2.56s	remaining: 5.69s
# 31:	learn: 0.1444028	total: 2.61s	remaining: 5.55s
# 32:	learn: 0.1417890	total: 2.69s	remaining: 5.47s
# 33:	learn: 0.1365533	total: 2.76s	remaining: 5.36s
# 34:	learn: 0.1328420	total: 2.82s	remaining: 5.23s
# 35:	learn: 0.1285242	total: 2.87s	remaining: 5.1s
# 36:	learn: 0.1258954	total: 2.92s	remaining: 4.97s
# 37:	learn: 0.1229135	total: 2.97s	remaining: 4.84s
# 38:	learn: 0.1205471	total: 3.01s	remaining: 4.71s
# 39:	learn: 0.1189355	total: 3.07s	remaining: 4.6s
# 40:	learn: 0.1162641	total: 3.14s	remaining: 4.52s
# 41:	learn: 0.1138822	total: 3.21s	remaining: 4.43s
# 42:	learn: 0.1121192	total: 3.36s	remaining: 4.45s
# 43:	learn: 0.1102616	total: 3.5s	remaining: 4.45s
# 44:	learn: 0.1077754	total: 3.56s	remaining: 4.35s
# 45:	learn: 0.1048527	total: 3.61s	remaining: 4.24s
# 46:	learn: 0.1039928	total: 3.67s	remaining: 4.13s
# 47:	learn: 0.1016875	total: 3.74s	remaining: 4.05s
# 48:	learn: 0.0996756	total: 3.79s	remaining: 3.95s
# 49:	learn: 0.0977987	total: 3.86s	remaining: 3.86s
# 50:	learn: 0.0961290	total: 3.92s	remaining: 3.77s
# 51:	learn: 0.0947920	total: 3.98s	remaining: 3.68s
# 52:	learn: 0.0939146	total: 4.04s	remaining: 3.58s
# 53:	learn: 0.0923596	total: 4.12s	remaining: 3.51s
# 54:	learn: 0.0917714	total: 4.19s	remaining: 3.43s
# 55:	learn: 0.0906279	total: 4.25s	remaining: 3.34s
# 56:	learn: 0.0893079	total: 4.3s	remaining: 3.25s
# 57:	learn: 0.0884540	total: 4.36s	remaining: 3.15s
# 58:	learn: 0.0879013	total: 4.4s	remaining: 3.06s
# 59:	learn: 0.0864277	total: 4.45s	remaining: 2.97s
# 60:	learn: 0.0844716	total: 4.5s	remaining: 2.88s
# 61:	learn: 0.0837294	total: 4.54s	remaining: 2.79s
# 62:	learn: 0.0831520	total: 4.59s	remaining: 2.7s
# 63:	learn: 0.0827204	total: 4.64s	remaining: 2.61s
# 64:	learn: 0.0818473	total: 4.69s	remaining: 2.52s
# 65:	learn: 0.0805653	total: 4.74s	remaining: 2.44s
# 66:	learn: 0.0801478	total: 4.79s	remaining: 2.36s
# 67:	learn: 0.0793563	total: 4.83s	remaining: 2.27s
# 68:	learn: 0.0787101	total: 4.88s	remaining: 2.19s
# 69:	learn: 0.0772892	total: 4.93s	remaining: 2.11s
# 70:	learn: 0.0761570	total: 4.97s	remaining: 2.03s
# 71:	learn: 0.0753045	total: 5.02s	remaining: 1.95s
# 72:	learn: 0.0745803	total: 5.06s	remaining: 1.87s
# 73:	learn: 0.0735358	total: 5.11s	remaining: 1.79s
# 74:	learn: 0.0720742	total: 5.15s	remaining: 1.72s
# 75:	learn: 0.0715039	total: 5.2s	remaining: 1.64s
# 76:	learn: 0.0707479	total: 5.24s	remaining: 1.57s
# 77:	learn: 0.0703182	total: 5.29s	remaining: 1.49s
# 78:	learn: 0.0695389	total: 5.33s	remaining: 1.42s
# 79:	learn: 0.0685374	total: 5.38s	remaining: 1.34s
# 80:	learn: 0.0679341	total: 5.42s	remaining: 1.27s
# 81:	learn: 0.0673835	total: 5.46s	remaining: 1.2s
# 82:	learn: 0.0667281	total: 5.5s	remaining: 1.13s
# 83:	learn: 0.0664878	total: 5.55s	remaining: 1.06s
# 84:	learn: 0.0644355	total: 5.62s	remaining: 992ms
# 85:	learn: 0.0637748	total: 5.67s	remaining: 924ms
# 86:	learn: 0.0633101	total: 5.72s	remaining: 855ms
# 87:	learn: 0.0619643	total: 5.78s	remaining: 788ms
# 88:	learn: 0.0616528	total: 5.83s	remaining: 721ms
# 89:	learn: 0.0607911	total: 5.89s	remaining: 654ms
# 90:	learn: 0.0601849	total: 5.94s	remaining: 588ms
# 91:	learn: 0.0597647	total: 5.99s	remaining: 521ms
# 92:	learn: 0.0594089	total: 6.05s	remaining: 455ms
# 93:	learn: 0.0590930	total: 6.1s	remaining: 389ms
# 94:	learn: 0.0585128	total: 6.14s	remaining: 323ms
# 95:	learn: 0.0582858	total: 6.21s	remaining: 259ms
# 96:	learn: 0.0580539	total: 6.26s	remaining: 194ms
# 97:	learn: 0.0571897	total: 6.32s	remaining: 129ms
# 98:	learn: 0.0567701	total: 6.37s	remaining: 64.3ms
# 99:	learn: 0.0560169	total: 6.43s	remaining: 0us
# <style  type="text/css" >
# #T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 55.2%, transparent 55.2%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 56.9%, transparent 56.9%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 49.0%, transparent 49.0%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 49.2%, transparent 49.2%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow2_col1,#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 47.6%, transparent 47.6%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 49.1%, transparent 49.1%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 47.1%, transparent 47.1%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow4_col1,#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 46.9%, transparent 46.9%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 47.8%, transparent 47.8%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 47.7%, transparent 47.7%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 44.6%, transparent 44.6%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 45.2%, transparent 45.2%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 41.6%, transparent 41.6%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 41.8%, transparent 41.8%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 37.0%, transparent 37.0%);
#         }#T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 38.0%, transparent 38.0%);
#         }</style><table id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776elevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow0_col0" class="data row0 col0" >Skl GBM</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow0_col1" class="data row0 col1" >55.192308</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow0_col2" class="data row0 col2" >56.891792</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow0_col3" class="data row0 col3" >215.861547</td>
#             </tr>
#             <tr>
#                         <th id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776elevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow1_col0" class="data row1 col0" >XGBoost</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow1_col1" class="data row1 col1" >48.961538</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow1_col2" class="data row1 col2" >49.221695</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow1_col3" class="data row1 col3" >34.673392</td>
#             </tr>
#             <tr>
#                         <th id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776elevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow2_col0" class="data row2 col0" >Random Forest</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow2_col1" class="data row2 col1" >47.642308</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow2_col2" class="data row2 col2" >49.132327</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow2_col3" class="data row2 col3" >16.900383</td>
#             </tr>
#             <tr>
#                         <th id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776elevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow3_col0" class="data row3 col0" >CatBoost</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow3_col1" class="data row3 col1" >47.130769</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow3_col2" class="data row3 col2" >47.556234</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow3_col3" class="data row3 col3" >13.150726</td>
#             </tr>
#             <tr>
#                         <th id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776elevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow4_col0" class="data row4 col0" >Skl HistGBM</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow4_col1" class="data row4 col1" >46.884615</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow4_col2" class="data row4 col2" >47.818454</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow4_col3" class="data row4 col3" >12.681199</td>
#             </tr>
#             <tr>
#                         <th id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776elevel0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow5_col0" class="data row5 col0" >LightGBM</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow5_col1" class="data row5 col1" >46.857692</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow5_col2" class="data row5 col2" >47.693064</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow5_col3" class="data row5 col3" >3.821743</td>
#             </tr>
#             <tr>
#                         <th id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776elevel0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow6_col0" class="data row6 col0" >Extra Trees</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow6_col1" class="data row6 col1" >44.580769</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow6_col2" class="data row6 col2" >45.162162</td>
#                         <td id="T_fde40e60_b0c1_11ec_9b2a_48a472d2776erow6
